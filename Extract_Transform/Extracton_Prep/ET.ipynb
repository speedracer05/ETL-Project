# %% [markdown]
# #### Summary

# %% [markdown]
# Compare how COVID-19 impacted to two coastal states – New York and California.  In order to do this, we  extracted COVID-19 data from three sources: covidtracking.com (csv, api), syracuse.com/coronovirus (scrapped)

# %%
# Import Dependencies and setup
import os
import pandas as pd
import time
import requests
import json
from urllib.request import urlopen
from bs4 import BeautifulSoup
# import psycopg2   # All SQL Loads should be done in a new .ipynb file

# %% [markdown]
# ##### Extraction

# %%
# Extract CSV into pandas df
df_ca = pd.read_csv('../resources/california-history.csv')
df_ca.head()
df_ca =len(df_ca)
print(df_ca)
# df_ca.dtypes  -- used to check data type. Uncomment to check
# Out:
# 369

# %% [markdown]
# ##### Generate List of Data Fields

# %%
# Create json url query and variable for data request
base_url = 'https://api.covidtracking.com/v1/states/ny/daily.json'
data_dict = requests.get(base_url).json()

print(json.dumps(data_dict, indent=4, sort_keys=True))
len(data_dict)
# Out:
# opleAntibody": null,
#         "negativeTestsViral": null,
#         "onVentilatorCumulative": null,
#         "onVentilatorCurrently": null,
#         "pending": null,
#         "posNeg": 251,
#         "positive": 251,
#         "positiveCasesViral": null,
#         "positiveIncrease": 56,
#         "positiveScore": 0,
#         "positiveTestsAntibody": null,
#         "positiveTestsAntigen": null,
#         "positiveTestsPeopleAntibody": null,
#         "positiveTestsPeopleAntigen": null,
#         "positiveTestsViral": null,
#         "probableCases": null,
#         "recovered": null,
#         "score": 0,
#         "state": "NY",
#         "total": 251,
#         "totalTestEncountersViral": 2074,
#         "totalTestResults": 2074,
#         "totalTestResultsIncrease": 553,
#         "totalTestResultsSource": "totalTestEncountersViral",
#         "totalTestsAntibody": null,
#         "totalTestsAntigen": null,
#         "totalTestsPeopleAntibody": null,
#         "totalTestsPeopleAntigen": null,
#         "totalTestsPeopleViral": null,
#         "totalTestsViral": null
#     },
#     {
#         "checkTimeEt": null,
#         "commercialScore": 0,
#         "dataQualityGrade": null,
#         "date": 20200311,
#         "dateChecked": null,
#         "dateModified": null,
#         "death": null,
#         "deathConfirmed": null,
#         "deathIncrease": 0,
#         "deathProbable": null,
#         "fips": "36",
#         "grade": "",
#         "hash": "5b970ce185791660ab76b08d73d94f8015919e9e",
#         "hospitalized": null,
#         "hospitalizedCumulative": null,
#         "hospitalizedCurrently": null,
#         "hospitalizedDischarged": null,
#         "hospitalizedIncrease": 0,
#         "inIcuCumulative": null,
#         "inIcuCurrently": null,
#         "lastUpdateEt": null,
#         "negative": null,
#         "negativeIncrease": 0,
#         "negativeRegularScore": 0,
#         "negativeScore": 0,
#         "negativeTestsAntibody": null,
#         "negativeTestsPeopleAntibody": null,
#         "negativeTestsViral": null,
#         "onVentilatorCumulative": null,
#         "onVentilatorCurrently": null,
#         "pending": null,
#         "posNeg": 195,
#         "positive": 195,
#         "positiveCasesViral": null,
#         "positiveIncrease": 44,
#         "positiveScore": 0,
#         "positiveTestsAntibody": null,
#         "positiveTestsAntigen": null,
#         "positiveTestsPeopleAntibody": null,
#         "positiveTestsPeopleAntigen": null,
#         "positiveTestsViral": null,
#         "probableCases": null,
#         "recovered": null,
#         "score": 0,
#         "state": "NY",
#         "total": 195,
#         "totalTestEncountersViral": 1521,
#         "totalTestResults": 1521,
#         "totalTestResultsIncrease": 425,
#         "totalTestResultsSource": "totalTestEncountersViral",
#         "totalTestsAntibody": null,
#         "totalTestsAntigen": null,
#         "totalTestsPeopleAntibody": null,
#         "totalTestsPeopleAntigen": null,
#         "totalTestsPeopleViral": null,
#         "totalTestsViral": null
#     },
#     {
#         "checkTimeEt": null,
#         "commercialScore": 0,
#         "dataQualityGrade": null,
#         "date": 20200310,
#         "dateChecked": null,
#         "dateModified": null,
#         "death": null,
#         "deathConfirmed": null,
#         "deathIncrease": 0,
#         "deathProbable": null,
#         "fips": "36",
#         "grade": "",
#         "hash": "add30e6fc2cdd69d3ab64f94472eed1fc93b61df",
#         "hospitalized": null,
#         "hospitalizedCumulative": null,
#         "hospitalizedCurrently": null,
#         "hospitalizedDischarged": null,
#         "hospitalizedIncrease": 0,
#         "inIcuCumulative": null,
#         "inIcuCurrently": null,
#         "lastUpdateEt": null,
#         "negative": null,
#         "negativeIncrease": 0,
#         "negativeRegularScore": 0,
#         "negativeScore": 0,
#         "negativeTestsAntibody": null,
#         "negativeTestsPeopleAntibody": null,
#         "negativeTestsViral": null,
#         "onVentilatorCumulative": null,
#         "onVentilatorCurrently": null,
#         "pending": null,
#         "posNeg": 151,
#         "positive": 151,
#         "positiveCasesViral": null,
#         "positiveIncrease": 63,
#         "positiveScore": 0,
#         "positiveTestsAntibody": null,
#         "positiveTestsAntigen": null,
#         "positiveTestsPeopleAntibody": null,
#         "positiveTestsPeopleAntigen": null,
#         "positiveTestsViral": null,
#         "probableCases": null,
#         "recovered": null,
#         "score": 0,
#         "state": "NY",
#         "total": 151,
#         "totalTestEncountersViral": 1096,
#         "totalTestResults": 1096,
#         "totalTestResultsIncrease": 401,
#         "totalTestResultsSource": "totalTestEncountersViral",
#         "totalTestsAntibody": null,
#         "totalTestsAntigen": null,
#         "totalTestsPeopleAntibody": null,
#         "totalTestsPeopleAntigen": null,
#         "totalTestsPeopleViral": null,
#         "totalTestsViral": null
#     },
#     {
#         "checkTimeEt": null,
#         "commercialScore": 0,
#         "dataQualityGrade": null,
#         "date": 20200309,
#         "dateChecked": null,
#         "dateModified": null,
#         "death": null,
#         "deathConfirmed": null,
#         "deathIncrease": 0,
#         "deathProbable": null,
#         "fips": "36",
#         "grade": "",
#         "hash": "e5b9a7b61793e3dfd6e7c941a3f02d6fa754fc48",
#         "hospitalized": null,
#         "hospitalizedCumulative": null,
#         "hospitalizedCurrently": null,
#         "hospitalizedDischarged": null,
#         "hospitalizedIncrease": 0,
#         "inIcuCumulative": null,
#         "inIcuCurrently": null,
#         "lastUpdateEt": null,
#         "negative": null,
#         "negativeIncrease": 0,
#         "negativeRegularScore": 0,
#         "negativeScore": 0,
#         "negativeTestsAntibody": null,
#         "negativeTestsPeopleAntibody": null,
#         "negativeTestsViral": null,
#         "onVentilatorCumulative": null,
#         "onVentilatorCurrently": null,
#         "pending": null,
#         "posNeg": 88,
#         "positive": 88,
#         "positiveCasesViral": null,
#         "positiveIncrease": 28,
#         "positiveScore": 0,
#         "positiveTestsAntibody": null,
#         "positiveTestsAntigen": null,
#         "positiveTestsPeopleAntibody": null,
#         "positiveTestsPeopleAntigen": null,
#         "positiveTestsViral": null,
#         "probableCases": null,
#         "recovered": null,
#         "score": 0,
#         "state": "NY",
#         "total": 88,
#         "totalTestEncountersViral": 695,
#         "totalTestResults": 695,
#         "totalTestResultsIncrease": 307,
#         "totalTestResultsSource": "totalTestEncountersViral",
#         "totalTestsAntibody": null,
#         "totalTestsAntigen": null,
#         "totalTestsPeopleAntibody": null,
#         "totalTestsPeopleAntigen": null,
#         "totalTestsPeopleViral": null,
#         "totalTestsViral": null
#     },
#     {
#         "checkTimeEt": null,
#         "commercialScore": 0,
#         "dataQualityGrade": null,
#         "date": 20200308,
#         "dateChecked": null,
#         "dateModified": null,
#         "death": null,
#         "deathConfirmed": null,
#         "deathIncrease": 0,
#         "deathProbable": null,
#         "fips": "36",
#         "grade": "",
#         "hash": "ffc2521d3a8b7d1db4c71fd3ed42e3f29e779a56",
#         "hospitalized": null,
#         "hospitalizedCumulative": null,
#         "hospitalizedCurrently": null,
#         "hospitalizedDischarged": null,
#         "hospitalizedIncrease": 0,
#         "inIcuCumulative": null,
#         "inIcuCurrently": null,
#         "lastUpdateEt": null,
#         "negative": null,
#         "negativeIncrease": 0,
#         "negativeRegularScore": 0,
#         "negativeScore": 0,
#         "negativeTestsAntibody": null,
#         "negativeTestsPeopleAntibody": null,
#         "negativeTestsViral": null,
#         "onVentilatorCumulative": null,
#         "onVentilatorCurrently": null,
#         "pending": null,
#         "posNeg": 60,
#         "positive": 60,
#         "positiveCasesViral": null,
#         "positiveIncrease": 24,
#         "positiveScore": 0,
#         "positiveTestsAntibody": null,
#         "positiveTestsAntigen": null,
#         "positiveTestsPeopleAntibody": null,
#         "positiveTestsPeopleAntigen": null,
#         "positiveTestsViral": null,
#         "probableCases": null,
#         "recovered": null,
#         "score": 0,
#         "state": "NY",
#         "total": 60,
#         "totalTestEncountersViral": 388,
#         "totalTestResults": 388,
#         "totalTestResultsIncrease": 200,
#         "totalTestResultsSource": "totalTestEncountersViral",
#         "totalTestsAntibody": null,
#         "totalTestsAntigen": null,
#         "totalTestsPeopleAntibody": null,
#         "totalTestsPeopleAntigen": null,
#         "totalTestsPeopleViral": null,
#         "totalTestsViral": null
#     },
#     {
#         "checkTimeEt": null,
#         "commercialScore": 0,
#         "dataQualityGrade": null,
#         "date": 20200307,
#         "dateChecked": null,
#         "dateModified": null,
#         "death": null,
#         "deathConfirmed": null,
#         "deathIncrease": 0,
#         "deathProbable": null,
#         "fips": "36",
#         "grade": "",
#         "hash": "d8b00fdd707cfcec7e7dd5f580a0fad157a1f86c",
#         "hospitalized": null,
#         "hospitalizedCumulative": null,
#         "hospitalizedCurrently": null,
#         "hospitalizedDischarged": null,
#         "hospitalizedIncrease": 0,
#         "inIcuCumulative": null,
#         "inIcuCurrently": null,
#         "lastUpdateEt": null,
#         "negative": null,
#         "negativeIncrease": 0,
#         "negativeRegularScore": 0,
#         "negativeScore": 0,
#         "negativeTestsAntibody": null,
#         "negativeTestsPeopleAntibody": null,
#         "negativeTestsViral": null,
#         "onVentilatorCumulative": null,
#         "onVentilatorCurrently": null,
#         "pending": 236,
#         "posNeg": 36,
#         "positive": 36,
#         "positiveCasesViral": null,
#         "positiveIncrease": 11,
#         "positiveScore": 0,
#         "positiveTestsAntibody": null,
#         "positiveTestsAntigen": null,
#         "positiveTestsPeopleAntibody": null,
#         "positiveTestsPeopleAntigen": null,
#         "positiveTestsViral": null,
#         "probableCases": null,
#         "recovered": null,
#         "score": 0,
#         "state": "NY",
#         "total": 272,
#         "totalTestEncountersViral": 188,
#         "totalTestResults": 188,
#         "totalTestResultsIncrease": 66,
#         "totalTestResultsSource": "totalTestEncountersViral",
#         "totalTestsAntibody": null,
#         "totalTestsAntigen": null,
#         "totalTestsPeopleAntibody": null,
#         "totalTestsPeopleAntigen": null,
#         "totalTestsPeopleViral": null,
#         "totalTestsViral": null
#     },
#     {
#         "checkTimeEt": null,
#         "commercialScore": 0,
#         "dataQualityGrade": null,
#         "date": 20200306,
#         "dateChecked": null,
#         "dateModified": null,
#         "death": null,
#         "deathConfirmed": null,
#         "deathIncrease": 0,
#         "deathProbable": null,
#         "fips": "36",
#         "grade": "",
#         "hash": "9e99ccc04e6d33397cc412ee1b0fbecddbaeecd8",
#         "hospitalized": null,
#         "hospitalizedCumulative": null,
#         "hospitalizedCurrently": null,
#         "hospitalizedDischarged": null,
#         "hospitalizedIncrease": 0,
#         "inIcuCumulative": null,
#         "inIcuCurrently": null,
#         "lastUpdateEt": null,
#         "negative": null,
#         "negativeIncrease": 0,
#         "negativeRegularScore": 0,
#         "negativeScore": 0,
#         "negativeTestsAntibody": null,
#         "negativeTestsPeopleAntibody": null,
#         "negativeTestsViral": null,
#         "onVentilatorCumulative": null,
#         "onVentilatorCurrently": null,
#         "pending": 236,
#         "posNeg": 25,
#         "positive": 25,
#         "positiveCasesViral": null,
#         "positiveIncrease": 22,
#         "positiveScore": 0,
#         "positiveTestsAntibody": null,
#         "positiveTestsAntigen": null,
#         "positiveTestsPeopleAntibody": null,
#         "positiveTestsPeopleAntigen": null,
#         "positiveTestsViral": null,
#         "probableCases": null,
#         "recovered": null,
#         "score": 0,
#         "state": "NY",
#         "total": 261,
#         "totalTestEncountersViral": 122,
#         "totalTestResults": 122,
#         "totalTestResultsIncrease": 92,
#         "totalTestResultsSource": "totalTestEncountersViral",
#         "totalTestsAntibody": null,
#         "totalTestsAntigen": null,
#         "totalTestsPeopleAntibody": null,
#         "totalTestsPeopleAntigen": null,
#         "totalTestsPeopleViral": null,
#         "totalTestsViral": null
#     },
#     {
#         "checkTimeEt": null,
#         "commercialScore": 0,
#         "dataQualityGrade": null,
#         "date": 20200305,
#         "dateChecked": null,
#         "dateModified": null,
#         "death": null,
#         "deathConfirmed": null,
#         "deathIncrease": 0,
#         "deathProbable": null,
#         "fips": "36",
#         "grade": "",
#         "hash": "04e82e80db72556a73999ead493c993e90b8969e",
#         "hospitalized": null,
#         "hospitalizedCumulative": null,
#         "hospitalizedCurrently": null,
#         "hospitalizedDischarged": null,
#         "hospitalizedIncrease": 0,
#         "inIcuCumulative": null,
#         "inIcuCurrently": null,
#         "lastUpdateEt": null,
#         "negative": null,
#         "negativeIncrease": 0,
#         "negativeRegularScore": 0,
#         "negativeScore": 0,
#         "negativeTestsAntibody": null,
#         "negativeTestsPeopleAntibody": null,
#         "negativeTestsViral": null,
#         "onVentilatorCumulative": null,
#         "onVentilatorCurrently": null,
#         "pending": 24,
#         "posNeg": 3,
#         "positive": 3,
#         "positiveCasesViral": null,
#         "positiveIncrease": 2,
#         "positiveScore": 0,
#         "positiveTestsAntibody": null,
#         "positiveTestsAntigen": null,
#         "positiveTestsPeopleAntibody": null,
#         "positiveTestsPeopleAntigen": null,
#         "positiveTestsViral": null,
#         "probableCases": null,
#         "recovered": null,
#         "score": 0,
#         "state": "NY",
#         "total": 27,
#         "totalTestEncountersViral": 30,
#         "totalTestResults": 30,
#         "totalTestResultsIncrease": 20,
#         "totalTestResultsSource": "totalTestEncountersViral",
#         "totalTestsAntibody": null,
#         "totalTestsAntigen": null,
#         "totalTestsPeopleAntibody": null,
#         "totalTestsPeopleAntigen": null,
#         "totalTestsPeopleViral": null,
#         "totalTestsViral": null
#     },
#     {
#         "checkTimeEt": null,
#         "commercialScore": 0,
#         "dataQualityGrade": null,
#         "date": 20200304,
#         "dateChecked": null,
#         "dateModified": null,
#         "death": null,
#         "deathConfirmed": 0,
#         "deathIncrease": 0,
#         "deathProbable": null,
#         "fips": "36",
#         "grade": "",
#         "hash": "3feb3bdb879194f81d11c8bbf994d8e3ea2a5252",
#         "hospitalized": null,
#         "hospitalizedCumulative": null,
#         "hospitalizedCurrently": null,
#         "hospitalizedDischarged": null,
#         "hospitalizedIncrease": 0,
#         "inIcuCumulative": null,
#         "inIcuCurrently": null,
#         "lastUpdateEt": null,
#         "negative": null,
#         "negativeIncrease": 0,
#         "negativeRegularScore": 0,
#         "negativeScore": 0,
#         "negativeTestsAntibody": null,
#         "negativeTestsPeopleAntibody": null,
#         "negativeTestsViral": null,
#         "onVentilatorCumulative": null,
#         "onVentilatorCurrently": null,
#         "pending": 24,
#         "posNeg": 1,
#         "positive": 1,
#         "positiveCasesViral": null,
#         "positiveIncrease": 0,
#         "positiveScore": 0,
#         "positiveTestsAntibody": null,
#         "positiveTestsAntigen": null,
#         "positiveTestsPeopleAntibody": null,
#         "positiveTestsPeopleAntigen": null,
#         "positiveTestsViral": null,
#         "probableCases": null,
#         "recovered": null,
#         "score": 0,
#         "state": "NY",
#         "total": 25,
#         "totalTestEncountersViral": 10,
#         "totalTestResults": 10,
#         "totalTestResultsIncrease": 9,
#         "totalTestResultsSource": "totalTestEncountersViral",
#         "totalTestsAntibody": null,
#         "totalTestsAntigen": null,
#         "totalTestsPeopleAntibody": null,
#         "totalTestsPeopleAntigen": null,
#         "totalTestsPeopleViral": null,
#         "totalTestsViral": null
#     },
#     {
#         "checkTimeEt": null,
#         "commercialScore": 0,
#         "dataQualityGrade": null,
#         "date": 20200303,
#         "dateChecked": null,
#         "dateModified": null,
#         "death": null,
#         "deathConfirmed": null,
#         "deathIncrease": 0,
#         "deathProbable": null,
#         "fips": "36",
#         "grade": "",
#         "hash": "9e3daed71a696c0c3fa30150ee6423a0a94de8f5",
#         "hospitalized": null,
#         "hospitalizedCumulative": null,
#         "hospitalizedCurrently": null,
#         "hospitalizedDischarged": null,
#         "hospitalizedIncrease": 0,
#         "inIcuCumulative": null,
#         "inIcuCurrently": null,
#         "lastUpdateEt": null,
#         "negative": null,
#         "negativeIncrease": 0,
#         "negativeRegularScore": 0,
#         "negativeScore": 0,
#         "negativeTestsAntibody": null,
#         "negativeTestsPeopleAntibody": null,
#         "negativeTestsViral": null,
#         "onVentilatorCumulative": null,
#         "onVentilatorCurrently": null,
#         "pending": null,
#         "posNeg": 1,
#         "positive": 1,
#         "positiveCasesViral": null,
#         "positiveIncrease": 1,
#         "positiveScore": 0,
#         "positiveTestsAntibody": null,
#         "positiveTestsAntigen": null,
#         "positiveTestsPeopleAntibody": null,
#         "positiveTestsPeopleAntigen": null,
#         "positiveTestsViral": null,
#         "probableCases": null,
#         "recovered": null,
#         "score": 0,
#         "state": "NY",
#         "total": 1,
#         "totalTestEncountersViral": 1,
#         "totalTestResults": 1,
#         "totalTestResultsIncrease": 1,
#         "totalTestResultsSource": "totalTestEncountersViral",
#         "totalTestsAntibody": null,
#         "totalTestsAntigen": null,
#         "totalTestsPeopleAntibody": null,
#         "totalTestsPeopleAntigen": null,
#         "totalTestsPeopleViral": null,
#         "totalTestsViral": null
#     },
#     {
#         "checkTimeEt": null,
#         "commercialScore": 0,
#         "dataQualityGrade": null,
#         "date": 20200302,
#         "dateChecked": null,
#         "dateModified": null,
#         "death": null,
#         "deathConfirmed": null,
#         "deathIncrease": 0,
#         "deathProbable": null,
#         "fips": "36",
#         "grade": "",
#         "hash": "b348e3592c0b30cb944b37ddbc88044ceeeadfc9",
#         "hospitalized": null,
#         "hospitalizedCumulative": null,
#         "hospitalizedCurrently": null,
#         "hospitalizedDischarged": null,
#         "hospitalizedIncrease": 0,
#         "inIcuCumulative": null,
#         "inIcuCurrently": null,
#         "lastUpdateEt": null,
#         "negative": null,
#         "negativeIncrease": 0,
#         "negativeRegularScore": 0,
#         "negativeScore": 0,
#         "negativeTestsAntibody": null,
#         "negativeTestsPeopleAntibody": null,
#         "negativeTestsViral": null,
#         "onVentilatorCumulative": null,
#         "onVentilatorCurrently": null,
#         "pending": null,
#         "posNeg": 0,
#         "positive": 0,
#         "positiveCasesViral": null,
#         "positiveIncrease": 0,
#         "positiveScore": 0,
#         "positiveTestsAntibody": null,
#         "positiveTestsAntigen": null,
#         "positiveTestsPeopleAntibody": null,
#         "positiveTestsPeopleAntigen": null,
#         "positiveTestsViral": null,
#         "probableCases": null,
#         "recovered": null,
#         "score": 0,
#         "state": "NY",
#         "total": 0,
#         "totalTestEncountersViral": 0,
#         "totalTestResults": 0,
#         "totalTestResultsIncrease": 0,
#         "totalTestResultsSource": "totalTestEncountersViral",
#         "totalTestsAntibody": null,
#         "totalTestsAntigen": null,
#         "totalTestsPeopleAntibody": null,
#         "totalTestsPeopleAntigen": null,
#         "totalTestsPeopleViral": null,
#         "totalTestsViral": null
#     }
# ]
# 371

# %%
# Set up dictionary of variables where data from api calls will be stored
ny_data = {'date':[], 'state':[], 'deaths':[], 
           'Icu hospitalized':[], 'positive cases viral':[], 'positive increase':[], 
           'test results total':[], 'test increase':[]
          }

print('Retrieving NY Covid data')
print('-' * 30)

# forLoop to collect data and append to data_dict
for data in data_dict:
#     try:  -- not working; keep to use in future
        ny_data['date'].append(data['date'])
        ny_data['state'].append(data['state'])
        ny_data['deaths'].append(data['deathIncrease'])
#         ny_data['daily_hospitalization'].append(data['hospitalizedIncrease'])
        ny_data['Icu hospitalized'].append(data['inIcuCurrently'])
        ny_data['positive cases viral'].append(data['positiveCasesViral'])
        ny_data['positive increase'].append(data['positiveIncrease'])
        ny_data['test results total'].append(data['totalTestResults'])
        ny_data['test increase'].append(data['totalTestResultsIncrease'])

        # Use timer to delay request to not exceed query limits.
        time.sleep(.075)
#     except:   -- not working; keep to use in future
#         print(f'Incomplete record for {data}. Skipping {data}.')

#         print(ny_data)  -- used to validate append to ny_data dictionary; uncomment to test
# Out:
# Retrieving NY Covid data
# ------------------------------

# %%
# Convert panda dictionary to dataframe and export to csv
ny_df = pd.DataFrame.from_dict(ny_data)

ny_df['date'] = pd.to_datetime(ny_df['date'], format='%Y%m%d')
ny_df.to_csv('../resources/ny_data.csv')
ny_df.head()
ny_df.dtypes  #-- used to check data type. Uncomment to check
# Out:
# date                    datetime64[ns]
# state                           object
# deaths                           int64
# Icu hospitalized               float64
# positive cases viral            object
# positive increase                int64
# test results total               int64
# test increase                    int64
# dtype: object

# %%
# Read in Cleaned CA Data

clean_ca_df = pd.read_csv('../resources/clean_ca_data.csv', index_col=0)

clean_ca_df.head()
# clean_ca_df.dtypes

# %%
# Merge CA and NY Data on Date
clean_ca_df['date'] = pd.to_datetime(clean_ca_df['date'], errors="coerce")
# CA_NY_Data = pd.merge(ny_df, clean_ca_df, how="inner", on="date")
CA_NY_Data = pd.concat([ny_df, clean_ca_df]).sort_index(kind="merge")
CA_NY_Data

# %%
CA_NY_Data = CA_NY_Data.rename(columns= {"date":"Date",
                                        "state":"State",
                                        "deaths":"Deaths",
                                        "Icu hospitalized":"ICU Hospitalizations",
                                        "positive cases viral": "Positive Viral Cases",
                                        "positive increase": "Positive Increase",
                                        "test results total": "Total Test Results",
                                        "test increase": "Test Increase",
                                        })
# CA_NY_Data = CA_NY_Data.dropna()
# CA_NY_Data = CA_NY_Data.reset_index(drop = True)
CA_NY_Data.fillna(0, inplace=True)

CA_NY_Data

# %% [markdown]
# ##### Scrape iframe

# %%
# Retrieve COVID graphs from Syracuse website iframes
# Set url query path
path='https://www.syracuse.com/coronavirus-ny/'
f = urlopen(path)
html = str(f.read())
soup = BeautifulSoup(html, 'html.parser')
txt = soup.find_all('iframe')

for element in txt:
    print(element.attrs["src"])

# %% [markdown]
# ##### Retrieve data from interactive chart

# %%
# Copied-pasted https://datawrapper.dwcdn.net/ijEiy/2/, a dynamic webpage 
# into browser and inspected page. Examined Network, then XHR to get the link for CSV data.
url = 'https://static.dwcdn.net/data/ijEiy.csv?v=1623222240000'
proxies = {}
response = requests.get(url=url, proxies=proxies)
with open("../resources/covid_chart_data.csv", "wb") as f:
    f.write(response.content)

# %%
CA_NY_Data.set_index('Date', inplace=True)
CA_NY_Data

# %%
CA_NY_Data.to_csv('../resources/CA_NY_Data2.csv')
