# %%
# Import Dependencies and setup
import pandas as pd
from sqlalchemy import create_engine
import time
import requests
import json

# %% [markdown]
# ##### Extraction

# %%
# Extract CSV into pandas df
df_ca = pd.read_csv('../resources/california-history.csv')
df_ca.head()
# Out:
#          date state    death  deathConfirmed  deathIncrease  deathProbable  \
# 0  2021-03-07    CA  54124.0             NaN            258            NaN
# 1  2021-03-06    CA  53866.0             NaN            418            NaN
# 2  2021-03-05    CA  53448.0             NaN            400            NaN
# 3  2021-03-04    CA  53048.0             NaN            273            NaN
# 4  2021-03-03    CA  52775.0             NaN            278            NaN
#
#    hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0           NaN                     NaN                 4291.0
# 1           NaN                     NaN                 4513.0
# 2           NaN                     NaN                 4714.0
# 3           NaN                     NaN                 4967.0
# 4           NaN                     NaN                 5110.0
#
#    hospitalizedIncrease  ...  totalTestResults  totalTestResultsIncrease  \
# 0                     0  ...          49646014                    133186
# 1                     0  ...          49512828                    218325
# 2                     0  ...          49294503                    146818
# 3                     0  ...          49147685                    119637
# 4                     0  ...          49028048                    130858
#
#    totalTestsAntibody  totalTestsAntigen  totalTestsPeopleAntibody  \
# 0                 NaN                NaN                       NaN
# 1                 NaN                NaN                       NaN
# 2                 NaN                NaN                       NaN
# 3                 NaN                NaN                       NaN
# 4                 NaN                NaN                       NaN
#
#    totalTestsPeopleAntigen  totalTestsPeopleViral  \
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                      NaN                    NaN
# 3                      NaN                    NaN
# 4                      NaN                    NaN
#
#    totalTestsPeopleViralIncrease  totalTestsViral  totalTestsViralIncrease
# 0                              0         49646014                   133186
# 1                              0         49512828                   218325
# 2                              0         49294503                   146818
# 3                              0         49147685                   119637
# 4                              0         49028048                   130858
#
# [5 rows x 41 columns]

# %% [markdown]
# ##### Drop Columns from Data

# %%
df_ca = df_ca[['date', 'state', 'deathIncrease', 'inIcuCurrently', 'positiveCasesViral', 'positiveIncrease', \
               'totalTestResults', 'totalTestResultsIncrease']]
df_ca.head()
# Out:
#          date state  deathIncrease  inIcuCurrently  positiveCasesViral  \
# 0  2021-03-07    CA            258          1159.0             3501394
# 1  2021-03-06    CA            418          1221.0             3497578
# 2  2021-03-05    CA            400          1236.0             3493126
# 3  2021-03-04    CA            273          1327.0             3488467
# 4  2021-03-03    CA            278          1403.0             3484963
#
#    positiveIncrease  totalTestResults  totalTestResultsIncrease
# 0              3816          49646014                    133186
# 1              4452          49512828                    218325
# 2              4659          49294503                    146818
# 3              3504          49147685                    119637
# 4              3352          49028048                    130858

# %% [markdown]
# ##### Rename Columns

# %%
clean_df_ca = df_ca.rename(columns={'deathIncrease' : 'deaths', 'hospitalizedIncrease' : 'daily hospitalization', \
                                   'inIcuCurrently' : 'Icu hospitalized', 'positiveCasesViral' : 'positive cases viral', \
                                    'positiveIncrease' : 'positive increase', 'totalTestResults' : 'test results total', \
                                    'totalTestResultsIncrease' : 'test increase'})
clean_df_ca.head()
# Out:
#          date state  deaths  Icu hospitalized  positive cases viral  \
# 0  2021-03-07    CA     258            1159.0               3501394
# 1  2021-03-06    CA     418            1221.0               3497578
# 2  2021-03-05    CA     400            1236.0               3493126
# 3  2021-03-04    CA     273            1327.0               3488467
# 4  2021-03-03    CA     278            1403.0               3484963
#
#    positive increase  test results total  test increase
# 0               3816            49646014         133186
# 1               4452            49512828         218325
# 2               4659            49294503         146818
# 3               3504            49147685         119637
# 4               3352            49028048         130858

# %% [markdown]
# ##### Replace NaN or Missing Values with 0

# %%
clean_df_ca.fillna(0)
# Out:
#            date state  deaths  Icu hospitalized  positiveCasesViral  \
# 0    2021-03-07    CA     258            1159.0             3501394
# 1    2021-03-06    CA     418            1221.0             3497578
# 2    2021-03-05    CA     400            1236.0             3493126
# 3    2021-03-04    CA     273            1327.0             3488467
# 4    2021-03-03    CA     278            1403.0             3484963
# ..          ...   ...     ...               ...                 ...
# 364  2020-03-08    CA       0               0.0                  88
# 365  2020-03-07    CA       0               0.0                  69
# 366  2020-03-06    CA       0               0.0                  60
# 367  2020-03-05    CA       0               0.0                  53
# 368  2020-03-04    CA       0               0.0                  53
#
#      positive increase  test results total  test increase
# 0                 3816            49646014         133186
# 1                 4452            49512828         218325
# 2                 4659            49294503         146818
# 3                 3504            49147685         119637
# 4                 3352            49028048         130858
# ..                 ...                 ...            ...
# 364                 19                 550             19
# 365                  9                 531              9
# 366                  7                 522              7
# 367                  0                 515              0
# 368                  0                 515              0
#
# [369 rows x 8 columns]
