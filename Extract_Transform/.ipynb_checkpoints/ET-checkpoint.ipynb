# %%
# Import Dependencies and setup
import pandas as pd
from sqlalchemy import create_engine
import time
import requests
import json

# %% [markdown]
# ##### Extraction

# %%
# Extract CSV into pandas df
df_ca = pd.read_csv('../resources/california-history.csv')
df_ca.head()
# Out:
#          date state    death  deathConfirmed  deathIncrease  deathProbable  \
# 0  2021-03-07    CA  54124.0             NaN            258            NaN
# 1  2021-03-06    CA  53866.0             NaN            418            NaN
# 2  2021-03-05    CA  53448.0             NaN            400            NaN
# 3  2021-03-04    CA  53048.0             NaN            273            NaN
# 4  2021-03-03    CA  52775.0             NaN            278            NaN
#
#    hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0           NaN                     NaN                 4291.0
# 1           NaN                     NaN                 4513.0
# 2           NaN                     NaN                 4714.0
# 3           NaN                     NaN                 4967.0
# 4           NaN                     NaN                 5110.0
#
#    hospitalizedIncrease  ...  totalTestResults  totalTestResultsIncrease  \
# ...

# %%
# Extract New York Covid data
base_url = "https://api.covidtracking.com/v2/states/ny/daily.json"
# Print response object
print(requests.get(url))

# Dictionary of variables where data from api calls will be stored
ny_data = {'date':[], 'state':[], 'deaths':[], 'daily_hospitalization':[], 'icu_hospitalized':[],
             'PositiveCasesViral':[], 'positive_increase':[], 'test_results_total':[], 'test_increase':[]}
# Out:
# <Response [200]>

# %%
 # Retrieving data and converting it into JSON
print(requests.get(url).json())
# Out:
# {'meta': {'build_time': '2021-05-10T23:47:51.938Z', 'license': 'CC-BY-4.0', 'version': '2.0-beta', 'field_definitions': [{'name': 'Total test results', 'field': 'tests.pcr.total', 'deprecated': False, 'prior_names': ['totalTestResults']}, {'name': 'Hospital discharges', 'deprecated': False, 'prior_names': []}, {'name': 'Confirmed Cases', 'field': 'cases.confirmed', 'deprecated': False, 'prior_names': ['positiveCasesViral']}, {'name': 'Cumulative hospitalized/Ever hospitalized', 'field': 'outcomes.hospitalized.total', 'deprecated': False, 'prior_names': ['hospitalizedCumulative']}, {'name': 'Cumulative in ICU/Ever in ICU', 'field': 'outcomes.hospitalized.in_icu', 'deprecated': False, 'prior_names': ['inIcuCumulative']}, {'name': 'Cumulative on ventilator/Ever on ventilator', 'field': 'hospitalization.on_ventilator.cumulative', 'deprecated': False, 'prior_names': ['onVentilatorCumulative']}, {'name': 'Currently hospitalized/Now hospitalized', 'field': 'hospitalization.hospitalized.curr
# ...

# %%
# Set ratelimit to prevent API calls from exceeding web services data rate
    
# Pretty Print the output of the JSON
response = requests.get(url).json()

pprint(json.dumps(response, indent=4, sort_keys=True))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
